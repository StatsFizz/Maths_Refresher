# %% [markdown]
# # Probability_temp

# %%
#import rpy2.rinterface

# %%
#%load_ext rpy2.ipython

# %% [markdown]
# ## Exponential rules

# %%
r <- rnorm(1000)
summary(r)

hist(r)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
# -2.995365 -0.703691 -0.010512 -0.009639  0.656487  3.175371
# Plot with title "Histogram of r"
