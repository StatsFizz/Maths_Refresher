# %% [markdown]
# # Probability_temp

# %%
#import rpy2.rinterface

# %%
#%load_ext rpy2.ipython

# %% [markdown]
# ## Exponential rules

# %%
r <- rnorm(1000)
summary(r)

hist(r)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -3.39804 -0.60738  0.03075  0.05898  0.76078  3.01810
# Plot with title "Histogram of r"
