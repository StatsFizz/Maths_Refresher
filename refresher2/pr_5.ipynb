# %% [markdown]
# # Probability_temp

# %% [markdown]
# ## Exponential rules

# %%
r <- rnorm(1000)
summary(r)

hist(r)
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
# -3.63139 -0.71183  0.01313 -0.02810  0.65320  3.42433
# Plot with title "Histogram of r"
